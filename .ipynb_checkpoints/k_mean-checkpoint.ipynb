# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Reads an image and read
img_file = './images/monroe.jpg'
img = cv2.imread(img_file)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
